# %%
import dagshub
import mlflow
dagshub.init(repo_owner='MohammedTawfikEldeeb', repo_name='telcom-churn', mlflow=True)
# Out:
# Accessing as MohammedTawfikEldeeb
# Initialized MLflow to track repo "MohammedTawfikEldeeb/telcom-churn"
# Repository MohammedTawfikEldeeb/telcom-churn initialized!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# split the dataset
from sklearn.model_selection import train_test_split


# preprossing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler , LabelEncoder , OrdinalEncoder
from sklearn.pipeline import Pipeline , FeatureUnion
from sklearn_features.transformers import DataFrameSelector
from datasist.structdata import detect_outliers
from sklearn.model_selection import cross_val_score, cross_val_predict
from imblearn.over_sampling import SMOTE ,RandomOverSampler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score , classification_report , confusion_matrix

# Models
from sklearn.linear_model import LogisticRegression , SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import AdaBoostClassifier , BaggingClassifier , GradientBoostingClassifier , RandomForestClassifier , VotingClassifier
from sklearn.multiclass import OneVsOneClassifier
import xgboost as xgb

# %%
df = pd.read_csv('data/data_processed.csv')
df.head()
# Out:
#    account_length  international_plan  voice_mail_plan  number_vmail_messages  \
# 0             128                   0                1                     25
# 1             107                   0                1                     26
# 2             137                   0                0                      0
# 3              84                   1                0                      0
# 4              75                   1                0                      0
#
#    customer_service_calls  churn  total_charge  total_minutes  total_calls
# 0                       1  False         75.56          717.2          303
# 1                       1  False         59.24          625.2          332
# 2                       0  False         62.29          539.4          333
# 3                       2  False         66.80          564.8          255
# 4                       3  False         52.09          512.0          359

# %%
outlieres_indicies = detect_outliers(df ,0, df.select_dtypes(include = ['float64' ,'int64']))
100*(len(outlieres_indicies)/df.shape[0])
# Out:
# 18.6018601860186

# %%
df.drop(outlieres_indicies , inplace = True)

# %%
x = df.drop('churn', axis=1)
y = df['churn']

x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.35, random_state=42, stratify=y, shuffle=True
)

# ----------- Scaling -----------
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# ----------- Oversampling only on train -----------
sampler = RandomOverSampler(random_state=42)
x_train_resampled, y_train_resampled = sampler.fit_resample(x_train_scaled, y_train)

# ----------- Models dictionary -----------
models = {
    'ovo': OneVsOneClassifier(estimator=RandomForestClassifier(random_state=42)),
    'knn': KNeighborsClassifier(),
    'SGD': SGDClassifier(random_state=42),
    'Lgr': LogisticRegression(max_iter=1000, random_state=42),
    'xgb': xgb.XGBClassifier(random_state=42),
    'dt': DecisionTreeClassifier(random_state=42),
    'RF': RandomForestClassifier(random_state=42),
    'bag': BaggingClassifier(random_state=42),
    'gdb': GradientBoostingClassifier(random_state=42),
    'SVC': SVC(),
    'baf_clf': BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap=True, random_state=42)
}

# ----------- Loop over models -----------
for model_name, model in models.items():
    with mlflow.start_run():
        mlflow.set_tag("mlflow.runName", f"{model_name}")
        mlflow.set_tag("experiment_type", "model_comparison")

        # Train model
        model.fit(x_train_resampled, y_train_resampled)
        y_pred = model.predict(x_test_scaled)

        # Metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("recall", recall)
        mlflow.log_metric("f1", f1)

        # Classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix {model_name}")
        plt.savefig(f"confusion_matrix_{model_name}.png")
        mlflow.log_artifact(f"confusion_matrix_{model_name}.png")

        # Dataset snapshot
        df.to_csv(f"dataset.csv", index=False)
        mlflow.log_artifact(f"dataset.csv")

    print(f"{model_name} -> Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f}")
# Out:
# 🏃 View run ovo at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/03a70cc8de8d4040ae5b8472fa681b2d
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# ovo -> Accuracy: 0.9758 | Precision: 0.9811 | Recall: 0.7027 | F1: 0.8189
# 🏃 View run knn at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/ec1599f7f4634ef7bbe8d8848651a29c
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# knn -> Accuracy: 0.8842 | Precision: 0.3696 | Recall: 0.6892 | F1: 0.4811
# 🏃 View run SGD at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/ce228c8c2ae24e9398a2918438d46dde
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# SGD -> Accuracy: 0.8116 | Precision: 0.2581 | Recall: 0.7568 | F1: 0.3849
# 🏃 View run Lgr at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/e68cffa2c1514ecbb1d9679d27a91b95
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# Lgr -> Accuracy: 0.7905 | Precision: 0.2407 | Recall: 0.7838 | F1: 0.3683
# 🏃 View run xgb at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/42ee8a44ab734fa9a4853067e2eab57d
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# xgb -> Accuracy: 0.9747 | Precision: 0.9630 | Recall: 0.7027 | F1: 0.8125
# 🏃 View run dt at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/e0d08ef3b72a4a9f9524a698511aa482
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# dt -> Accuracy: 0.9505 | Precision: 0.6709 | Recall: 0.7162 | F1: 0.6928
# 🏃 View run RF at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/0714a31b9ff347618242419398a453ed
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# RF -> Accuracy: 0.9758 | Precision: 0.9811 | Recall: 0.7027 | F1: 0.8189
# 🏃 View run bag at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/21c8a605806743698980ff3553ba1434
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# bag -> Accuracy: 0.9705 | Precision: 0.8966 | Recall: 0.7027 | F1: 0.7879
# 🏃 View run gdb at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/7de551f0054f41188f50d67043dd3939
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# gdb -> Accuracy: 0.9684 | Precision: 0.8667 | Recall: 0.7027 | F1: 0.7761
# 🏃 View run SVC at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/729bfb4beed5458392d0c885a73f033c
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# SVC -> Accuracy: 0.9211 | Precision: 0.4953 | Recall: 0.7162 | F1: 0.5856
# 🏃 View run baf_clf at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0/runs/046b438f44bc420a94ff27233dcf03d3
# 🧪 View experiment at: https://dagshub.com/MohammedTawfikEldeeb/telcom-churn.mlflow/#/experiments/0
# baf_clf -> Accuracy: 0.9737 | Precision: 0.9455 | Recall: 0.7027 | F1: 0.8062
